# %%
VALID = True
import time

notebookstart = time.time()

import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc

path = "/Users/um003580/projects/kaggle/avito/input"

print("Data:\n", os.listdir(path))

# Models Packages
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn import feature_selection
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# Gradient Boosting
import lightgbm as lgb

# Tf-Idf
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import FeatureUnion
from scipy.sparse import hstack, csr_matrix
from nltk.corpus import stopwords

# Viz
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Data:
#  ['test_active.csv', 'train_active.csv', 'periods_train.csv', 'test.csv', 'train_jpg_0', 'test_active.csv.zip', 'aggregated_features.csv', 'periods_test.csv', 'train.csv', 'sample_submission.csv']

# %%
# Thanks You Guillaume Martin for the Awesome Memory Optimizer!
# https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.
    """
    start_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
print("\nData Load Stage")
training = pd.read_csv(path+'/train.csv', index_col="item_id", parse_dates=["activation_date"])  # .sample(1000)
traindex = training.index
testing = pd.read_csv(path+'/test.csv', index_col="item_id", parse_dates=["activation_date"])  # .sample(1000)
testdex = testing.index
y = training.deal_probability.copy().clip(0.0, 1.0)
training.drop("deal_probability", axis=1, inplace=True)
print('Train shape: {} Rows, {} Columns'.format(*training.shape))
print('Test shape: {} Rows, {} Columns'.format(*testing.shape))
# Out:
# Data Load Stage
# Train shape: 1503424 Rows, 16 Columns
# Test shape: 508438 Rows, 16 Columns

# %%
print("Combine Train and Test")
df = pd.concat([training, testing], axis=0)
del training, testing
gc.collect()
print('\nAll Data shape: {} Rows, {} Columns'.format(*df.shape))
# Out:
# Combine Train and Test
#
# All Data shape: 2011862 Rows, 16 Columns

# %%
print("Feature Engineering")
df["price"] = np.log(df["price"] + 0.001)
# df["price"].fillna(-999, inplace=True)
df["image_top_1"].fillna(-999, inplace=True)

print("\nCreate Time Variables")
df["Weekday"] = df['activation_date'].dt.weekday
df["Weekd of Year"] = df['activation_date'].dt.week
df["Day of Month"] = df['activation_date'].dt.day

# Create Validation Index and Remove Dead Variables
# training_index = df.loc[df.activation_date<=pd.to_datetime('2017-04-07')].index
# validation_index = df.loc[df.activation_date>=pd.to_datetime('2017-04-08')].index
df.drop(["activation_date", "image"], axis=1, inplace=True)
# Out:
# Feature Engineering
#
# Create Time Variables

# %%
ag = pd.read_csv(path+'/aggregated_features.csv')
df = df.merge(ag, on='user_id', how='left').set_index(df.index)
df.head()
# Out:
#                    user_id                 region              city  \
# item_id
# b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 2dac0150717d  39aeb48f0017      Самарская область            Самара
# ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#              parent_category_name               category_name  \
# item_id
# b912c3c6a6ad          Личные вещи  Товары для детей и игрушки
# 2dac0150717d      Для дома и дачи           Мебель и интерьер
# ba83aefab5dc  Бытовая электроника               Аудио и видео
# 02996f1dd2ea          Личные вещи  Товары для детей и игрушки
# 7c90be56d2ab            Транспорт                  Автомобили
#
#                                   param_1     param_2 param_3  \
# item_id
# b912c3c6a6ad    Постельные принадлежности         NaN     NaN
# 2dac0150717d                       Другое         NaN     NaN
# ba83aefab5dc  Видео, DVD и Blu-ray плееры         NaN     NaN
# 02996f1dd2ea         Автомобильные кресла         NaN     NaN
# 7c90be56d2ab                   С пробегом  ВАЗ (LADA)    2110
#
#                               title  \
# item_id
# b912c3c6a6ad  Кокоби(кокон для сна)
# 2dac0150717d      Стойка для Одежды
# ba83aefab5dc         Philips bluray
# 02996f1dd2ea             Автокресло
# 7c90be56d2ab         ВАЗ 2110, 2003
#
#                                                     description      price  \
# item_id
# b912c3c6a6ad  Кокон для сна малыша,пользовались меньше месяц...   5.991467
# 2dac0150717d          Стойка для одежды, под вешалки. С бутика.   8.006368
# ba83aefab5dc  В хорошем состоянии, домашний кинотеатр с blu ...   8.294050
# 02996f1dd2ea                             Продам кресло от0-25кг   7.696213
# 7c90be56d2ab                           Все вопросы по телефону.  10.596635
#
#               item_seq_number user_type  image_top_1  Weekday  Weekd of Year  \
# item_id
# b912c3c6a6ad                2   Private       1008.0        1             13
# 2dac0150717d               19   Private        692.0        6             12
# ba83aefab5dc                9   Private       3032.0        0             12
# 02996f1dd2ea              286   Company        796.0        5             12
# 7c90be56d2ab                3   Private       2264.0        3             11
#
#               Day of Month  avg_days_up_user  avg_times_up_user  n_user_items
# item_id
# b912c3c6a6ad            28          8.000000           2.000000             2
# 2dac0150717d            26               NaN                NaN             1
# ba83aefab5dc            20          4.428571           1.142857             9
# 02996f1dd2ea            25         16.714286           2.642857            32
# 7c90be56d2ab            16               NaN                NaN             1

# %%
print("\nEncode Variables")
categorical = ["user_id", "region", "city", "parent_category_name", "category_name", "user_type",
               "image_top_1", "param_1", "param_2", "param_3"]
print("Encoding :", categorical)

# Encoder:
lbl = preprocessing.LabelEncoder()
for col in categorical:
    df[col] = lbl.fit_transform(df[col].astype(str))
# Out:
# Encode Variables
# Encoding : ['user_id', 'region', 'city', 'parent_category_name', 'category_name', 'user_type', 'image_top_1', 'param_1', 'param_2', 'param_3']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/um003580/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print("\nText Features")
# Feature Engineering
# Meta Text Features
textfeats = ["description", "title"]

for cols in textfeats:
    df[cols] = df[cols].astype(str)
    df[cols] = df[cols].astype(str).fillna('missing')  # FILL NA
    df[cols] = df[cols].str.lower()  # Lowercase all text, so that capitalized words dont get treated differently
    df[cols + '_num_words'] = df[cols].apply(lambda comment: len(comment.split()))  # Count number of Words
    df[cols + '_num_unique_words'] = df[cols].apply(lambda comment: len(set(w for w in comment.split())))
    df[cols + '_words_vs_unique'] = df[cols + '_num_unique_words'] / df[cols + '_num_words'] * 100  # Count Unique Words
# Out:
# Text Features

# %%
print("\n[TF-IDF] Term Frequency Inverse Document Frequency Stage")
russian_stop = set(stopwords.words('russian'))

tfidf_para = {
    "stop_words": russian_stop,
    "analyzer": 'word',
    "token_pattern": r'\w{1,}',
    "sublinear_tf": True,
    "dtype": np.float32,
    "norm": 'l2',
    # "min_df":5,
    # "max_df":.9,
    "smooth_idf": False
}


def get_col(col_name): return lambda x: x[col_name]


##I added to the max_features of the description. It did not change my score much but it may be worth investigating
vectorizer = FeatureUnion([
    ('description', TfidfVectorizer(
        ngram_range=(1, 2),
        max_features=17000,
        **tfidf_para,
        preprocessor=get_col('description'))),
    ('title', CountVectorizer(
        ngram_range=(1, 2),
        stop_words=russian_stop,
        # max_features=7000,
        preprocessor=get_col('title')))
])

start_vect = time.time()

# Fit my vectorizer on the entire dataset instead of the training rows
# Score improved by .0001
vectorizer.fit(df.to_dict('records'))
ready_df = vectorizer.transform(df.to_dict('records'))
# Out:
# [TF-IDF] Term Frequency Inverse Document Frequency Stage

# %%
tfvocab = vectorizer.get_feature_names()
print("Vectorization Runtime: %0.2f Minutes" % ((time.time() - start_vect) / 60))

# Drop Text Cols
df.drop(textfeats, axis=1, inplace=True)

# Dense Features Correlation Matrix
# f, ax = plt.subplots(figsize=[10, 7])
# sns.heatmap(pd.concat([df.loc[traindex, [x for x in df.columns if x not in categorical]], y], axis=1).corr(),
#             annot=False, fmt=".2f", cbar_kws={'label': 'Correlation Coefficient'}, cmap="plasma", ax=ax, linewidths=.5)
# ax.set_title("Dense Features Correlation Matrix")
# plt.savefig('correlation_matrix.png')

print("Modeling Stage")
# Reduce Memory (See function up top)
df = reduce_mem_usage(df)
# Out:
# Vectorization Runtime: 7.44 Minutes
# Modeling Stage
# Memory usage of dataframe is 383.73 MB
# Memory usage after optimization is: 97.85 MB
# Decreased by 74.5%

# %%
#pikle化
import pickle
with open('df.csv.pkl','wb') as f:
  pickle.dump(df,f,protocol=4)

with open('y.csv.pkl','wb') as f:
  pickle.dump(y,f,protocol=4)

# %%
import pickle
# with timer("Loading done"):
with open('df.csv.pkl','rb') as f:
    df = pickle.load(f)

with open('y.csv.pkl','rb') as f:
    y = pickle.load(f)

# %%
# df['price'].replace({-999: np.nan}, inplace=True)

# %%
df.head(50)
# Out:
#               user_id  region  city  parent_category_name  category_name  \
# item_id
# b912c3c6a6ad   884270      19   462                     4             42
# 2dac0150717d   227908      17  1314                     2             22
# ba83aefab5dc   576261      16  1290                     0              2
# 02996f1dd2ea   755087      21   950                     4             42
# 7c90be56d2ab   944363       4   318                     6              0
# 51e0962387f7   741761      21  1675                     4             42
# c4f260a2b48a    35292      11   985                     2             38
# 6b71309d6a8a  1005882      15  1164                     4             29
# c5b969cb63a2    20909      14  1118                     4             29
# b1570962e68c   985900      11   985                     4             10
# d5480bb4a6e4   838226      25  1620                     5             15
# 86f41f50d8c1   212396      23   498                     4             29
# 645237cb3601   996594      14  1118                     4             42
# df2116f34563   240447      16  1290                     0             44
# a97943ae8158   971547       1  1541                     3             39
# 4b6abd0a5921   587958      21   589                     4             29
# 7896ef8fe482     1912       9   730                     6              0
# 7882b1e77748   483255      12  1059                     4             42
# 071e1ed13c5c   198783      13   933                     4             29
# 0658628930d4   156610       2   137                     5             11
# ea12aec32ec3    27354      12   151                     5             15
# 838a82cec0a6   368640      19   462                     4             29
# de310e6aae86     5804      26   865                     6              0
# 08b24e170109   403921      16  1290                     4             10
# 065a4daba35f   101262      11   985                     3             43
# 990113ae4f1c   859061       5   330                     4             42
# 78164bc09657   451408      17  1523                     2             22
# fbe29970a8a5   185660       8  1034                     4             29
# 71d9399b59a2   593832      18  1319                     4             29
# 4941f0385575   830748      11   985                     4             10
# af9d5b0eadc9  1006974      16    22                     2             38
# 1b080aa4a17d   414881      11   985                     3             12
# d0e88acda491   340889      15  1164                     0             44
# c559542570bd    79889      21   589                     5             19
# 2285e797fe2d   353715      18  1319                     6              0
# 3cb58a3d1d60   548695       9    67                     4             42
# f5259a31c938   568053       3   313                     4             29
# dd65da44086c   755469       4   318                     8             17
# f55eed4e831e   500075       7   356                     5             18
# eddd320650f3   577957       5   330                     4             29
# 078d07e4548b   269086      26  1650                     4             10
# b865b1ea7621   541101      25  1204                     4             10
# 208faac9e776   988950      15  1164                     4             10
# 50ac2bb95f8d   216172       4   318                     4             29
# 745d124338ae  1009642      10   750                     5             15
# 75076ea12736   505427      10   750                     2             33
# a58ab9e6a0b1   474081      18  1319                     2             22
# 8c7c7596d7e5   103833      10   750                     4             42
# 16cec7b5dc9d   185733      21   589                     4             42
# a285d4daec8a   913412      15  1164                     4             21
#
#               param_1  param_2  param_3      price  item_seq_number  \
# item_id
# b912c3c6a6ad      249      112     1217   5.992188                2
# 2dac0150717d      122      112     1217   8.007812               19
# ba83aefab5dc       84      112     1217   8.296875                9
# 02996f1dd2ea       38      112     1217   7.695312              286
# 7c90be56d2ab      278      124       46  10.593750                3
# 51e0962387f7       38      112     1217   7.171875                9
# c4f260a2b48a      283      112     1217   9.304688              125
# 6b71309d6a8a      126      141       75   6.214844               61
# c5b969cb63a2      126      208      219   6.214844               85
# b1570962e68c      105      198       74   5.992188              136
# d5480bb4a6e4      284      193        0   9.796875                6
# 86f41f50d8c1      126      141     1225   0.000999                4
# 645237cb3601      325      112     1217   4.250000               15
# df2116f34563      201      112     1217   7.824219               47
# a97943ae8158      214      112     1217   8.515625                6
# 4b6abd0a5921      126      208      144   6.683594               86
# 7896ef8fe482      278       27      696  11.851562              201
# 7882b1e77748      134      112     1217   6.214844                9
# 071e1ed13c5c      126      127      149   6.906250                4
# 0658628930d4      297      172     1257  11.515625                5
# ea12aec32ec3      258        1     1229  14.375000              461
# 838a82cec0a6      126      127      219   7.863281               33
# de310e6aae86      278       41      546  12.421875               12
# 08b24e170109      105      198       74   7.171875               59
# 065a4daba35f       32      112     1217        NaN              310
# 990113ae4f1c      134      112     1217   7.312500              309
# 78164bc09657      317      112     1217   6.906250               59
# fbe29970a8a5      126      198      120   7.312500                8
# 71d9399b59a2      126      208      155   6.906250               12
# 4941f0385575      110      147     1217   5.296875               20
# af9d5b0eadc9      311      112     1217        NaN                8
# 1b080aa4a17d      279      112     1217   4.867188               18
# d0e88acda491      166      240     1217   5.703125             3377
# c559542570bd      258      112     1217  13.710938              385
# 2285e797fe2d      278       15      190  11.085938                1
# 3cb58a3d1d60      102      112     1217   9.101562               67
# f5259a31c938      207      198      139   8.296875               80
# dd65da44086c      127      112     1217   6.683594              295
# f55eed4e831e      258      241     1217  13.593750             6004
# eddd320650f3      126      198      120   6.906250               11
# 078d07e4548b      110      121       16   5.703125               65
# b865b1ea7621      110      163      185   6.214844               13
# 208faac9e776      105      272     1217   6.214844               74
# 50ac2bb95f8d      207      258      150   5.992188             2062
# 745d124338ae      258        0     1229  14.648438            10714
# 75076ea12736      324      112     1217   5.859375               13
# a58ab9e6a0b1      317      112     1217   6.398438              204
# 8c7c7596d7e5      100      112     1217   6.214844                8
# 16cec7b5dc9d      102      112     1217   7.601562               28
# a285d4daec8a      254      112     1217   8.515625                1
#
#                       ...            Day of Month  avg_days_up_user  \
# item_id               ...
# b912c3c6a6ad          ...                      28          8.000000
# 2dac0150717d          ...                      26               NaN
# ba83aefab5dc          ...                      20          4.429688
# 02996f1dd2ea          ...                      25         16.718750
# 7c90be56d2ab          ...                      16               NaN
# 51e0962387f7          ...                      28          4.000000
# c4f260a2b48a          ...                      23          7.332031
# 6b71309d6a8a          ...                      25         11.914062
# c5b969cb63a2          ...                      17         13.515625
# b1570962e68c          ...                      22         15.632812
# d5480bb4a6e4          ...                      25               NaN
# 86f41f50d8c1          ...                      19               NaN
# 645237cb3601          ...                      21               NaN
# df2116f34563          ...                      22         12.710938
# a97943ae8158          ...                      23          9.500000
# 4b6abd0a5921          ...                      27         13.796875
# 7896ef8fe482          ...                      18          3.000000
# 7882b1e77748          ...                      20               NaN
# 071e1ed13c5c          ...                      24          4.000000
# 0658628930d4          ...                      28               NaN
# ea12aec32ec3          ...                      17         13.000000
# 838a82cec0a6          ...                      16          9.617188
# de310e6aae86          ...                      20               NaN
# 08b24e170109          ...                      20         12.085938
# 065a4daba35f          ...                      16         15.500000
# 990113ae4f1c          ...                      24         10.796875
# 78164bc09657          ...                      26         16.312500
# fbe29970a8a5          ...                      27         13.000000
# 71d9399b59a2          ...                      25          6.000000
# 4941f0385575          ...                      19         13.109375
# af9d5b0eadc9          ...                      25               NaN
# 1b080aa4a17d          ...                      28          9.164062
# d0e88acda491          ...                      18         12.820312
# c559542570bd          ...                      21          9.906250
# 2285e797fe2d          ...                      25               NaN
# 3cb58a3d1d60          ...                      27         11.335938
# f5259a31c938          ...                      24         16.875000
# dd65da44086c          ...                      23         15.507812
# f55eed4e831e          ...                      28          9.796875
# eddd320650f3          ...                      17          5.667969
# 078d07e4548b          ...                      23         10.429688
# b865b1ea7621          ...                      28         10.203125
# 208faac9e776          ...                      15          6.000000
# 50ac2bb95f8d          ...                      15          9.960938
# 745d124338ae          ...                      24         11.992188
# 75076ea12736          ...                      20         10.445312
# a58ab9e6a0b1          ...                      22         16.015625
# 8c7c7596d7e5          ...                      17         16.000000
# 16cec7b5dc9d          ...                      18         15.000000
# a285d4daec8a          ...                      17               NaN
#
#               avg_times_up_user  n_user_items  description_num_words  \
# item_id
# b912c3c6a6ad           2.000000             2                      7
# 2dac0150717d                NaN             1                      7
# ba83aefab5dc           1.142578             9                     17
# 02996f1dd2ea           2.642578            32                      3
# 7c90be56d2ab                NaN             1                      4
# 51e0962387f7           1.000000             2                      3
# c4f260a2b48a           1.222656            11                     21
# 6b71309d6a8a           1.666992            23                      4
# c5b969cb63a2           1.896484            38                      5
# b1570962e68c           2.046875            93                     11
# d5480bb4a6e4                NaN             1                     11
# 86f41f50d8c1                NaN            10                      1
# 645237cb3601                NaN             9                     20
# df2116f34563           1.142578             9                      7
# a97943ae8158           1.500000             5                      6
# 4b6abd0a5921           1.900391            22                     31
# 7896ef8fe482           1.000000             2                     61
# 7882b1e77748                NaN             3                      5
# 071e1ed13c5c           1.000000             3                     11
# 0658628930d4                NaN             5                     43
# ea12aec32ec3           1.500000            21                     34
# 838a82cec0a6           1.307617            15                     17
# de310e6aae86                NaN             1                     19
# 08b24e170109           1.647461            39                      6
# 065a4daba35f           2.250000             6                     66
# 990113ae4f1c           1.400391            14                     32
# 78164bc09657           2.416016            37                      6
# fbe29970a8a5           1.000000             2                      7
# 71d9399b59a2           1.000000             4                      9
# 4941f0385575           1.444336            15                      4
# af9d5b0eadc9                NaN             3                     68
# 1b080aa4a17d           1.333008             8                      9
# d0e88acda491           1.749023           847                    336
# c559542570bd           1.406250            41                     98
# 2285e797fe2d                NaN             1                     42
# 3cb58a3d1d60           1.500000            25                     40
# f5259a31c938           2.562500            19                     14
# dd65da44086c           2.482422            99                     46
# f55eed4e831e           1.472656          1174                     19
# eddd320650f3           1.000000             4                      7
# 078d07e4548b           2.427734            31                     12
# b865b1ea7621           1.799805             6                     23
# 208faac9e776           1.333008            13                     78
# 50ac2bb95f8d           1.074219            80                     15
# 745d124338ae           1.724609           129                     13
# 75076ea12736           2.000000            14                      1
# a58ab9e6a0b1           2.328125            68                     37
# 8c7c7596d7e5           3.000000             7                      1
# 16cec7b5dc9d           2.000000            10                     13
# a285d4daec8a                NaN             1                     24
#
#               description_num_unique_words  description_words_vs_unique  \
# item_id
# b912c3c6a6ad                             7                     100.0000
# 2dac0150717d                             7                     100.0000
# ba83aefab5dc                            17                     100.0000
# 02996f1dd2ea                             3                     100.0000
# 7c90be56d2ab                             4                     100.0000
# 51e0962387f7                             3                     100.0000
# c4f260a2b48a                            19                      90.5000
# 6b71309d6a8a                             4                     100.0000
# c5b969cb63a2                             5                     100.0000
# b1570962e68c                            11                     100.0000
# d5480bb4a6e4                            11                     100.0000
# 86f41f50d8c1                             1                     100.0000
# 645237cb3601                            14                      70.0000
# df2116f34563                             7                     100.0000
# a97943ae8158                             6                     100.0000
# 4b6abd0a5921                            29                      93.5625
# 7896ef8fe482                            51                      83.6250
# 7882b1e77748                             5                     100.0000
# 071e1ed13c5c                            11                     100.0000
# 0658628930d4                            41                      95.3750
# ea12aec32ec3                            34                     100.0000
# 838a82cec0a6                            17                     100.0000
# de310e6aae86                            19                     100.0000
# 08b24e170109                             6                     100.0000
# 065a4daba35f                            32                      48.5000
# 990113ae4f1c                            29                      90.6250
# 78164bc09657                             6                     100.0000
# fbe29970a8a5                             7                     100.0000
# 71d9399b59a2                             9                     100.0000
# 4941f0385575                             4                     100.0000
# af9d5b0eadc9                            63                      92.6250
# 1b080aa4a17d                             9                     100.0000
# d0e88acda491                           247                      73.5000
# c559542570bd                            82                      83.6875
# 2285e797fe2d                            40                      95.2500
# 3cb58a3d1d60                            37                      92.5000
# f5259a31c938                            14                     100.0000
# dd65da44086c                            43                      93.5000
# f55eed4e831e                            19                     100.0000
# eddd320650f3                             7                     100.0000
# 078d07e4548b                            11                      91.6875
# b865b1ea7621                            21                      91.3125
# 208faac9e776                            72                      92.3125
# 50ac2bb95f8d                            15                     100.0000
# 745d124338ae                            12                      92.3125
# 75076ea12736                             1                     100.0000
# a58ab9e6a0b1                            37                     100.0000
# 8c7c7596d7e5                             1                     100.0000
# 16cec7b5dc9d                            13                     100.0000
# a285d4daec8a                            23                      95.8125
#
#               title_num_words  title_num_unique_words  title_words_vs_unique
# item_id
# b912c3c6a6ad                3                       3                  100.0
# 2dac0150717d                3                       3                  100.0
# ba83aefab5dc                2                       2                  100.0
# 02996f1dd2ea                1                       1                  100.0
# 7c90be56d2ab                3                       3                  100.0
# 51e0962387f7                2                       2                  100.0
# c4f260a2b48a                5                       5                  100.0
# 6b71309d6a8a                2                       2                  100.0
# c5b969cb63a2                1                       1                  100.0
# b1570962e68c                4                       4                  100.0
# d5480bb4a6e4                6                       6                  100.0
# 86f41f50d8c1                1                       1                  100.0
# 645237cb3601                7                       7                  100.0
# df2116f34563                3                       3                  100.0
# a97943ae8158                4                       4                  100.0
# 4b6abd0a5921                3                       3                  100.0
# 7896ef8fe482                3                       3                  100.0
# 7882b1e77748                3                       3                  100.0
# 071e1ed13c5c                2                       2                  100.0
# 0658628930d4                2                       2                  100.0
# ea12aec32ec3                6                       6                  100.0
# 838a82cec0a6                2                       2                  100.0
# de310e6aae86                3                       3                  100.0
# 08b24e170109                2                       2                  100.0
# 065a4daba35f                2                       2                  100.0
# 990113ae4f1c                5                       5                  100.0
# 78164bc09657                1                       1                  100.0
# fbe29970a8a5                1                       1                  100.0
# 71d9399b59a2                3                       3                  100.0
# 4941f0385575                2                       2                  100.0
# af9d5b0eadc9                2                       2                  100.0
# 1b080aa4a17d                1                       1                  100.0
# d0e88acda491                5                       5                  100.0
# c559542570bd                7                       7                  100.0
# 2285e797fe2d                3                       3                  100.0
# 3cb58a3d1d60                3                       3                  100.0
# f5259a31c938                4                       4                  100.0
# dd65da44086c                6                       6                  100.0
# f55eed4e831e                3                       3                  100.0
# eddd320650f3                2                       2                  100.0
# 078d07e4548b                2                       2                  100.0
# b865b1ea7621                3                       3                  100.0
# 208faac9e776                3                       3                  100.0
# 50ac2bb95f8d                4                       4                  100.0
# 745d124338ae                6                       6                  100.0
# 75076ea12736                3                       3                  100.0
# a58ab9e6a0b1                4                       4                  100.0
# 8c7c7596d7e5                3                       3                  100.0
# 16cec7b5dc9d                3                       3                  100.0
# a285d4daec8a                3                       3                  100.0
#
# [50 rows x 24 columns]

# %%
y.head()
# Out:
# item_id
# b912c3c6a6ad    0.12789
# 2dac0150717d    0.00000
# ba83aefab5dc    0.43177
# 02996f1dd2ea    0.80323
# 7c90be56d2ab    0.20797
# Name: deal_probability, dtype: float64

# %%
parent_prices = df.groupby('parent_category_name').agg({'price':['mean','median']}).reset_index()
parent_prices.columns = ['parent_category_name','parent_category_mean','parent_category_median']
parent_prices.head(10)
# Out:
#    parent_category_name  parent_category_mean  parent_category_median
# 0                     0              7.781250                7.882812
# 1                     1              9.843750                9.906250
# 2                     2              7.378906                7.601562
# 3                     3              6.207031                6.906250
# 4                     4              6.613281                6.535156
# 5                     5             13.187500               14.070312
# 6                     6             12.132812               12.304688
# 7                     7              5.878906                6.214844
# 8                     8              7.246094                7.312500

# %%
df = pd.merge(df, parent_prices, on='parent_category_name',how='left').set_index(df.index)

# %%
prices = df.groupby('category_name').agg({'price':['mean','median']}).reset_index()
prices.columns = ['category_name','category_mean','category_median']
prices.head(10)
# Out:
#    category_name  category_mean  category_median
# 0              0      12.281250        12.375000
# 1              1       6.023438         6.214844
# 2              2       7.601562         7.601562
# 3              3       8.828125         9.210938
# 4              4       7.925781         8.007812
# 5              5       8.289062         8.453125
# 6              6      10.804688        10.671875
# 7              7      11.281250        11.921875
# 8              8      12.273438        12.609375
# 9              9      12.515625        12.609375

# %%
df = pd.merge(df, prices, on='category_name',how='left').set_index(df.index)

# %%
del parent_prices,prices

# %%
df.head(20)
# Out:
#               user_id  region  city  parent_category_name  category_name  \
# item_id
# b912c3c6a6ad   884270      19   462                     4             42
# 2dac0150717d   227908      17  1314                     2             22
# ba83aefab5dc   576261      16  1290                     0              2
# 02996f1dd2ea   755087      21   950                     4             42
# 7c90be56d2ab   944363       4   318                     6              0
# 51e0962387f7   741761      21  1675                     4             42
# c4f260a2b48a    35292      11   985                     2             38
# 6b71309d6a8a  1005882      15  1164                     4             29
# c5b969cb63a2    20909      14  1118                     4             29
# b1570962e68c   985900      11   985                     4             10
# d5480bb4a6e4   838226      25  1620                     5             15
# 86f41f50d8c1   212396      23   498                     4             29
# 645237cb3601   996594      14  1118                     4             42
# df2116f34563   240447      16  1290                     0             44
# a97943ae8158   971547       1  1541                     3             39
# 4b6abd0a5921   587958      21   589                     4             29
# 7896ef8fe482     1912       9   730                     6              0
# 7882b1e77748   483255      12  1059                     4             42
# 071e1ed13c5c   198783      13   933                     4             29
# 0658628930d4   156610       2   137                     5             11
#
#               param_1  param_2  param_3      price  item_seq_number  \
# item_id
# b912c3c6a6ad      249      112     1217   5.992188                2
# 2dac0150717d      122      112     1217   8.007812               19
# ba83aefab5dc       84      112     1217   8.296875                9
# 02996f1dd2ea       38      112     1217   7.695312              286
# 7c90be56d2ab      278      124       46  10.593750                3
# 51e0962387f7       38      112     1217   7.171875                9
# c4f260a2b48a      283      112     1217   9.304688              125
# 6b71309d6a8a      126      141       75   6.214844               61
# c5b969cb63a2      126      208      219   6.214844               85
# b1570962e68c      105      198       74   5.992188              136
# d5480bb4a6e4      284      193        0   9.796875                6
# 86f41f50d8c1      126      141     1225   0.000999                4
# 645237cb3601      325      112     1217   4.250000               15
# df2116f34563      201      112     1217   7.824219               47
# a97943ae8158      214      112     1217   8.515625                6
# 4b6abd0a5921      126      208      144   6.683594               86
# 7896ef8fe482      278       27      696  11.851562              201
# 7882b1e77748      134      112     1217   6.214844                9
# 071e1ed13c5c      126      127      149   6.906250                4
# 0658628930d4      297      172     1257  11.515625                5
#
#                    ...         description_num_words  \
# item_id            ...
# b912c3c6a6ad       ...                             7
# 2dac0150717d       ...                             7
# ba83aefab5dc       ...                            17
# 02996f1dd2ea       ...                             3
# 7c90be56d2ab       ...                             4
# 51e0962387f7       ...                             3
# c4f260a2b48a       ...                            21
# 6b71309d6a8a       ...                             4
# c5b969cb63a2       ...                             5
# b1570962e68c       ...                            11
# d5480bb4a6e4       ...                            11
# 86f41f50d8c1       ...                             1
# 645237cb3601       ...                            20
# df2116f34563       ...                             7
# a97943ae8158       ...                             6
# 4b6abd0a5921       ...                            31
# 7896ef8fe482       ...                            61
# 7882b1e77748       ...                             5
# 071e1ed13c5c       ...                            11
# 0658628930d4       ...                            43
#
#               description_num_unique_words  description_words_vs_unique  \
# item_id
# b912c3c6a6ad                             7                     100.0000
# 2dac0150717d                             7                     100.0000
# ba83aefab5dc                            17                     100.0000
# 02996f1dd2ea                             3                     100.0000
# 7c90be56d2ab                             4                     100.0000
# 51e0962387f7                             3                     100.0000
# c4f260a2b48a                            19                      90.5000
# 6b71309d6a8a                             4                     100.0000
# c5b969cb63a2                             5                     100.0000
# b1570962e68c                            11                     100.0000
# d5480bb4a6e4                            11                     100.0000
# 86f41f50d8c1                             1                     100.0000
# 645237cb3601                            14                      70.0000
# df2116f34563                             7                     100.0000
# a97943ae8158                             6                     100.0000
# 4b6abd0a5921                            29                      93.5625
# 7896ef8fe482                            51                      83.6250
# 7882b1e77748                             5                     100.0000
# 071e1ed13c5c                            11                     100.0000
# 0658628930d4                            41                      95.3750
#
#               title_num_words  title_num_unique_words  title_words_vs_unique  \
# item_id
# b912c3c6a6ad                3                       3                  100.0
# 2dac0150717d                3                       3                  100.0
# ba83aefab5dc                2                       2                  100.0
# 02996f1dd2ea                1                       1                  100.0
# 7c90be56d2ab                3                       3                  100.0
# 51e0962387f7                2                       2                  100.0
# c4f260a2b48a                5                       5                  100.0
# 6b71309d6a8a                2                       2                  100.0
# c5b969cb63a2                1                       1                  100.0
# b1570962e68c                4                       4                  100.0
# d5480bb4a6e4                6                       6                  100.0
# 86f41f50d8c1                1                       1                  100.0
# 645237cb3601                7                       7                  100.0
# df2116f34563                3                       3                  100.0
# a97943ae8158                4                       4                  100.0
# 4b6abd0a5921                3                       3                  100.0
# 7896ef8fe482                3                       3                  100.0
# 7882b1e77748                3                       3                  100.0
# 071e1ed13c5c                2                       2                  100.0
# 0658628930d4                2                       2                  100.0
#
#               parent_category_mean  parent_category_median  category_mean  \
# item_id
# b912c3c6a6ad              6.613281                6.535156       7.234375
# 2dac0150717d              7.378906                7.601562       7.808594
# ba83aefab5dc              7.781250                7.882812       7.601562
# 02996f1dd2ea              6.613281                6.535156       7.234375
# 7c90be56d2ab             12.132812               12.304688      12.281250
# 51e0962387f7              6.613281                6.535156       7.234375
# c4f260a2b48a              7.378906                7.601562       7.304688
# 6b71309d6a8a              6.613281                6.535156       6.804688
# c5b969cb63a2              6.613281                6.535156       6.804688
# b1570962e68c              6.613281                6.535156       6.132812
# d5480bb4a6e4             13.187500               14.070312      13.414062
# 86f41f50d8c1              6.613281                6.535156       6.804688
# 645237cb3601              6.613281                6.535156       7.234375
# df2116f34563              7.781250                7.882812       6.921875
# a97943ae8158              6.207031                6.906250       6.449219
# 4b6abd0a5921              6.613281                6.535156       6.804688
# 7896ef8fe482             12.132812               12.304688      12.281250
# 7882b1e77748              6.613281                6.535156       7.234375
# 071e1ed13c5c              6.613281                6.535156       6.804688
# 0658628930d4             13.187500               14.070312      13.726562
#
#               category_median
# item_id
# b912c3c6a6ad         7.312500
# 2dac0150717d         8.007812
# ba83aefab5dc         7.601562
# 02996f1dd2ea         7.312500
# 7c90be56d2ab        12.375000
# 51e0962387f7         7.312500
# c4f260a2b48a         7.601562
# 6b71309d6a8a         6.800781
# c5b969cb63a2         6.800781
# b1570962e68c         6.214844
# d5480bb4a6e4        14.343750
# 86f41f50d8c1         6.800781
# 645237cb3601         7.312500
# df2116f34563         6.906250
# a97943ae8158         8.515625
# 4b6abd0a5921         6.800781
# 7896ef8fe482        12.375000
# 7882b1e77748         7.312500
# 071e1ed13c5c         6.800781
# 0658628930d4        14.078125
#
# [20 rows x 28 columns]

# %%
df['parent_category_mean_diff'] = df['price'] - df['parent_category_mean']
df['parent_category_median_diff'] = df['price'] - df['parent_category_median']
df['category_mean_diff'] = df['price'] - df['category_mean']
df['category_median_diff'] = df['price'] - df['category_median']

# %%
df.head(30)
# Out:
#               user_id  region  city  parent_category_name  category_name  \
# item_id
# b912c3c6a6ad   884270      19   462                     4             42
# 2dac0150717d   227908      17  1314                     2             22
# ba83aefab5dc   576261      16  1290                     0              2
# 02996f1dd2ea   755087      21   950                     4             42
# 7c90be56d2ab   944363       4   318                     6              0
# 51e0962387f7   741761      21  1675                     4             42
# c4f260a2b48a    35292      11   985                     2             38
# 6b71309d6a8a  1005882      15  1164                     4             29
# c5b969cb63a2    20909      14  1118                     4             29
# b1570962e68c   985900      11   985                     4             10
# d5480bb4a6e4   838226      25  1620                     5             15
# 86f41f50d8c1   212396      23   498                     4             29
# 645237cb3601   996594      14  1118                     4             42
# df2116f34563   240447      16  1290                     0             44
# a97943ae8158   971547       1  1541                     3             39
# 4b6abd0a5921   587958      21   589                     4             29
# 7896ef8fe482     1912       9   730                     6              0
# 7882b1e77748   483255      12  1059                     4             42
# 071e1ed13c5c   198783      13   933                     4             29
# 0658628930d4   156610       2   137                     5             11
# ea12aec32ec3    27354      12   151                     5             15
# 838a82cec0a6   368640      19   462                     4             29
# de310e6aae86     5804      26   865                     6              0
# 08b24e170109   403921      16  1290                     4             10
# 065a4daba35f   101262      11   985                     3             43
# 990113ae4f1c   859061       5   330                     4             42
# 78164bc09657   451408      17  1523                     2             22
# fbe29970a8a5   185660       8  1034                     4             29
# 71d9399b59a2   593832      18  1319                     4             29
# 4941f0385575   830748      11   985                     4             10
#
#               param_1  param_2  param_3      price  item_seq_number  \
# item_id
# b912c3c6a6ad      249      112     1217   5.992188                2
# 2dac0150717d      122      112     1217   8.007812               19
# ba83aefab5dc       84      112     1217   8.296875                9
# 02996f1dd2ea       38      112     1217   7.695312              286
# 7c90be56d2ab      278      124       46  10.593750                3
# 51e0962387f7       38      112     1217   7.171875                9
# c4f260a2b48a      283      112     1217   9.304688              125
# 6b71309d6a8a      126      141       75   6.214844               61
# c5b969cb63a2      126      208      219   6.214844               85
# b1570962e68c      105      198       74   5.992188              136
# d5480bb4a6e4      284      193        0   9.796875                6
# 86f41f50d8c1      126      141     1225   0.000999                4
# 645237cb3601      325      112     1217   4.250000               15
# df2116f34563      201      112     1217   7.824219               47
# a97943ae8158      214      112     1217   8.515625                6
# 4b6abd0a5921      126      208      144   6.683594               86
# 7896ef8fe482      278       27      696  11.851562              201
# 7882b1e77748      134      112     1217   6.214844                9
# 071e1ed13c5c      126      127      149   6.906250                4
# 0658628930d4      297      172     1257  11.515625                5
# ea12aec32ec3      258        1     1229  14.375000              461
# 838a82cec0a6      126      127      219   7.863281               33
# de310e6aae86      278       41      546  12.421875               12
# 08b24e170109      105      198       74   7.171875               59
# 065a4daba35f       32      112     1217        NaN              310
# 990113ae4f1c      134      112     1217   7.312500              309
# 78164bc09657      317      112     1217   6.906250               59
# fbe29970a8a5      126      198      120   7.312500                8
# 71d9399b59a2      126      208      155   6.906250               12
# 4941f0385575      110      147     1217   5.296875               20
#
#                       ...           title_num_unique_words  \
# item_id               ...
# b912c3c6a6ad          ...                                3
# 2dac0150717d          ...                                3
# ba83aefab5dc          ...                                2
# 02996f1dd2ea          ...                                1
# 7c90be56d2ab          ...                                3
# 51e0962387f7          ...                                2
# c4f260a2b48a          ...                                5
# 6b71309d6a8a          ...                                2
# c5b969cb63a2          ...                                1
# b1570962e68c          ...                                4
# d5480bb4a6e4          ...                                6
# 86f41f50d8c1          ...                                1
# 645237cb3601          ...                                7
# df2116f34563          ...                                3
# a97943ae8158          ...                                4
# 4b6abd0a5921          ...                                3
# 7896ef8fe482          ...                                3
# 7882b1e77748          ...                                3
# 071e1ed13c5c          ...                                2
# 0658628930d4          ...                                2
# ea12aec32ec3          ...                                6
# 838a82cec0a6          ...                                2
# de310e6aae86          ...                                3
# 08b24e170109          ...                                2
# 065a4daba35f          ...                                2
# 990113ae4f1c          ...                                5
# 78164bc09657          ...                                1
# fbe29970a8a5          ...                                1
# 71d9399b59a2          ...                                3
# 4941f0385575          ...                                2
#
#               title_words_vs_unique  parent_category_mean  \
# item_id
# b912c3c6a6ad                  100.0              6.613281
# 2dac0150717d                  100.0              7.378906
# ba83aefab5dc                  100.0              7.781250
# 02996f1dd2ea                  100.0              6.613281
# 7c90be56d2ab                  100.0             12.132812
# 51e0962387f7                  100.0              6.613281
# c4f260a2b48a                  100.0              7.378906
# 6b71309d6a8a                  100.0              6.613281
# c5b969cb63a2                  100.0              6.613281
# b1570962e68c                  100.0              6.613281
# d5480bb4a6e4                  100.0             13.187500
# 86f41f50d8c1                  100.0              6.613281
# 645237cb3601                  100.0              6.613281
# df2116f34563                  100.0              7.781250
# a97943ae8158                  100.0              6.207031
# 4b6abd0a5921                  100.0              6.613281
# 7896ef8fe482                  100.0             12.132812
# 7882b1e77748                  100.0              6.613281
# 071e1ed13c5c                  100.0              6.613281
# 0658628930d4                  100.0             13.187500
# ea12aec32ec3                  100.0             13.187500
# 838a82cec0a6                  100.0              6.613281
# de310e6aae86                  100.0             12.132812
# 08b24e170109                  100.0              6.613281
# 065a4daba35f                  100.0              6.207031
# 990113ae4f1c                  100.0              6.613281
# 78164bc09657                  100.0              7.378906
# fbe29970a8a5                  100.0              6.613281
# 71d9399b59a2                  100.0              6.613281
# 4941f0385575                  100.0              6.613281
#
#               parent_category_median  category_mean  category_median  \
# item_id
# b912c3c6a6ad                6.535156       7.234375         7.312500
# 2dac0150717d                7.601562       7.808594         8.007812
# ba83aefab5dc                7.882812       7.601562         7.601562
# 02996f1dd2ea                6.535156       7.234375         7.312500
# 7c90be56d2ab               12.304688      12.281250        12.375000
# 51e0962387f7                6.535156       7.234375         7.312500
# c4f260a2b48a                7.601562       7.304688         7.601562
# 6b71309d6a8a                6.535156       6.804688         6.800781
# c5b969cb63a2                6.535156       6.804688         6.800781
# b1570962e68c                6.535156       6.132812         6.214844
# d5480bb4a6e4               14.070312      13.414062        14.343750
# 86f41f50d8c1                6.535156       6.804688         6.800781
# 645237cb3601                6.535156       7.234375         7.312500
# df2116f34563                7.882812       6.921875         6.906250
# a97943ae8158                6.906250       6.449219         8.515625
# 4b6abd0a5921                6.535156       6.804688         6.800781
# 7896ef8fe482               12.304688      12.281250        12.375000
# 7882b1e77748                6.535156       7.234375         7.312500
# 071e1ed13c5c                6.535156       6.804688         6.800781
# 0658628930d4               14.070312      13.726562        14.078125
# ea12aec32ec3               14.070312      13.414062        14.343750
# 838a82cec0a6                6.535156       6.804688         6.800781
# de310e6aae86               12.304688      12.281250        12.375000
# 08b24e170109                6.535156       6.132812         6.214844
# 065a4daba35f                6.906250       6.382812         6.398438
# 990113ae4f1c                6.535156       7.234375         7.312500
# 78164bc09657                7.601562       7.808594         8.007812
# fbe29970a8a5                6.535156       6.804688         6.800781
# 71d9399b59a2                6.535156       6.804688         6.800781
# 4941f0385575                6.535156       6.132812         6.214844
#
#               parent_category_mean_diff  parent_category_median_diff  \
# item_id
# b912c3c6a6ad                  -0.621094                    -0.542969
# 2dac0150717d                   0.628906                     0.406250
# ba83aefab5dc                   0.515625                     0.414062
# 02996f1dd2ea                   1.082031                     1.160156
# 7c90be56d2ab                  -1.539062                    -1.710938
# 51e0962387f7                   0.558594                     0.636719
# c4f260a2b48a                   1.925781                     1.703125
# 6b71309d6a8a                  -0.398438                    -0.320312
# c5b969cb63a2                  -0.398438                    -0.320312
# b1570962e68c                  -0.621094                    -0.542969
# d5480bb4a6e4                  -3.390625                    -4.273438
# 86f41f50d8c1                  -6.613281                    -6.535156
# 645237cb3601                  -2.363281                    -2.285156
# df2116f34563                   0.042969                    -0.058594
# a97943ae8158                   2.308594                     1.609375
# 4b6abd0a5921                   0.070312                     0.148438
# 7896ef8fe482                  -0.281250                    -0.453125
# 7882b1e77748                  -0.398438                    -0.320312
# 071e1ed13c5c                   0.292969                     0.371094
# 0658628930d4                  -1.671875                    -2.554688
# ea12aec32ec3                   1.187500                     0.304688
# 838a82cec0a6                   1.250000                     1.328125
# de310e6aae86                   0.289062                     0.117188
# 08b24e170109                   0.558594                     0.636719
# 065a4daba35f                        NaN                          NaN
# 990113ae4f1c                   0.699219                     0.777344
# 78164bc09657                  -0.472656                    -0.695312
# fbe29970a8a5                   0.699219                     0.777344
# 71d9399b59a2                   0.292969                     0.371094
# 4941f0385575                  -1.316406                    -1.238281
#
#               category_mean_diff  category_median_diff
# item_id
# b912c3c6a6ad           -1.242188             -1.320312
# 2dac0150717d            0.199219              0.000000
# ba83aefab5dc            0.695312              0.695312
# 02996f1dd2ea            0.460938              0.382812
# 7c90be56d2ab           -1.687500             -1.781250
# 51e0962387f7           -0.062500             -0.140625
# c4f260a2b48a            2.000000              1.703125
# 6b71309d6a8a           -0.589844             -0.585938
# c5b969cb63a2           -0.589844             -0.585938
# b1570962e68c           -0.140625             -0.222656
# d5480bb4a6e4           -3.617188             -4.546875
# 86f41f50d8c1           -6.804688             -6.800781
# 645237cb3601           -2.984375             -3.062500
# df2116f34563            0.902344              0.917969
# a97943ae8158            2.066406              0.000000
# 4b6abd0a5921           -0.121094             -0.117188
# 7896ef8fe482           -0.429688             -0.523438
# 7882b1e77748           -1.019531             -1.097656
# 071e1ed13c5c            0.101562              0.105469
# 0658628930d4           -2.210938             -2.562500
# ea12aec32ec3            0.960938              0.031250
# 838a82cec0a6            1.058594              1.062500
# de310e6aae86            0.140625              0.046875
# 08b24e170109            1.039062              0.957031
# 065a4daba35f                 NaN                   NaN
# 990113ae4f1c            0.078125              0.000000
# 78164bc09657           -0.902344             -1.101562
# fbe29970a8a5            0.507812              0.511719
# 71d9399b59a2            0.101562              0.105469
# 4941f0385575           -0.835938             -0.917969
#
# [30 rows x 32 columns]

# %%
# Combine Dense Features with Sparse Text Bag of Words Features
X = hstack([csr_matrix(df.loc[traindex, :].values), ready_df[0:traindex.shape[0]]])  # Sparse Matrix
testing = hstack([csr_matrix(df.loc[testdex, :].values), ready_df[traindex.shape[0]:]])
tfvocab = df.columns.tolist() + tfvocab
for shape in [X, testing]:
    print("{} Rows and {} Cols".format(*shape.shape))
print("Feature Names Length: ", len(tfvocab))
del df, ready_df
gc.collect();
# Out:
# 1503424 Rows and 1430255 Cols
# 508438 Rows and 1430255 Cols
# Feature Names Length:  1430255

# %%
print("\nModeling Stage")
print("Light Gradient Boosting Regressor")

n_rounds = 5000
lgbm_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    # 'max_depth': 5,
    'num_leaves': 31,
    # 'feature_fraction': 0.65,
    'bagging_fraction': 0.9,
    'min_sum_hessian_in_leaf': 1,
    'lambda_l1': 0.4,
    'lambda_l2': 0.6,
    'seed': 99,
    # 'bagging_freq': 5,
    'learning_rate': 0.05,
    'verbose': 0
}

# Training and Validation Set
modelstart = time.time()
if VALID == True:
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, test_size=0.10, random_state=99)

    # LGBM Dataset Formatting
    lgtrain = lgb.Dataset(X_train, y_train,
                          feature_name=tfvocab,
                          categorical_feature=categorical)
    lgvalid = lgb.Dataset(X_valid, y_valid,
                          feature_name=tfvocab,
                          categorical_feature=categorical)
    del X, X_train;
    gc.collect()

    # Go Go Go
    lgb_clf = lgb.train(
        lgbm_params,
        lgtrain,
        num_boost_round=n_rounds,
        valid_sets=[lgvalid],
        valid_names=['valid'],
        early_stopping_rounds=50,
        verbose_eval=20
    )
    print("Model Evaluation Stage")
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_valid, lgb_clf.predict(X_valid))))
    del X_valid;
    gc.collect()

else:
    # LGBM Dataset Formatting
    lgtrain = lgb.Dataset(X, y,
                          feature_name=tfvocab,
                          categorical_feature=categorical)
    del X;
    gc.collect()
    # Go Go Go
    lgb_clf = lgb.train(
        lgbm_params,
        lgtrain,
        num_boost_round=n_rounds,
        verbose_eval=20
    )
# Out:
# Modeling Stage
# Light Gradient Boosting Regressor
# /Users/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /Users/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# Training until validation scores don't improve for 50 rounds.
# [20]	valid's rmse: 0.235449
# [40]	valid's rmse: 0.229928
# [60]	valid's rmse: 0.227834
# [80]	valid's rmse: 0.226578
# [100]	valid's rmse: 0.225715
# [120]	valid's rmse: 0.225098
# [140]	valid's rmse: 0.224573
# [160]	valid's rmse: 0.224166
# [180]	valid's rmse: 0.223805
# [200]	valid's rmse: 0.22352
# [220]	valid's rmse: 0.223243
# [240]	valid's rmse: 0.223027
# [260]	valid's rmse: 0.222826
# [280]	valid's rmse: 0.222635
# [300]	valid's rmse: 0.222475
# [320]	valid's rmse: 0.222327
# [340]	valid's rmse: 0.222217
# [360]	valid's rmse: 0.222082
# [380]	valid's rmse: 0.221974
# [400]	valid's rmse: 0.22185
# [420]	valid's rmse: 0.221749
# [440]	valid's rmse: 0.221655
# [460]	valid's rmse: 0.221563
# [480]	valid's rmse: 0.221471
# [500]	valid's rmse: 0.221383
# [520]	valid's rmse: 0.221313
# [540]	valid's rmse: 0.221252
# [560]	valid's rmse: 0.221174
# [580]	valid's rmse: 0.221115
# [600]	valid's rmse: 0.221057
# [620]	valid's rmse: 0.221003
# [640]	valid's rmse: 0.220958
# [660]	valid's rmse: 0.220901
# [680]	valid's rmse: 0.220854
# [700]	valid's rmse: 0.220802
# [720]	valid's rmse: 0.220753
# [740]	valid's rmse: 0.220702
# [760]	valid's rmse: 0.220662
# [780]	valid's rmse: 0.220621
# [800]	valid's rmse: 0.220577
# [820]	valid's rmse: 0.220538
# [840]	valid's rmse: 0.220498
# [860]	valid's rmse: 0.220463
# [880]	valid's rmse: 0.22043
# [900]	valid's rmse: 0.220397
# [920]	valid's rmse: 0.220347
# [940]	valid's rmse: 0.220318
# [960]	valid's rmse: 0.220293
# [980]	valid's rmse: 0.220269
# [1000]	valid's rmse: 0.220234
# [1020]	valid's rmse: 0.220198
# [1040]	valid's rmse: 0.220177
# [1060]	valid's rmse: 0.220148
# [1080]	valid's rmse: 0.220134
# [1100]	valid's rmse: 0.220107
# [1120]	valid's rmse: 0.220084
# [1140]	valid's rmse: 0.220067
# [1160]	valid's rmse: 0.220046
# [1180]	valid's rmse: 0.220021
# [1200]	valid's rmse: 0.22
# [1220]	valid's rmse: 0.219983
# [1240]	valid's rmse: 0.219957
# [1260]	valid's rmse: 0.219938
# [1280]	valid's rmse: 0.219922
# [1300]	valid's rmse: 0.219899
# [1320]	valid's rmse: 0.219878
# [1340]	valid's rmse: 0.219858
# [1360]	valid's rmse: 0.219833
# [1380]	valid's rmse: 0.219811
# [1400]	valid's rmse: 0.219797
# [1420]	valid's rmse: 0.219782
# [1440]	valid's rmse: 0.219769
# [1460]	valid's rmse: 0.219745
# [1480]	valid's rmse: 0.219725
# [1500]	valid's rmse: 0.219702
# [1520]	valid's rmse: 0.219686
# [1540]	valid's rmse: 0.21967
# [1560]	valid's rmse: 0.219652
# [1580]	valid's rmse: 0.219639
# [1600]	valid's rmse: 0.219623
# [1620]	valid's rmse: 0.219605
# [1640]	valid's rmse: 0.219595
# [1660]	valid's rmse: 0.21958
# [1680]	valid's rmse: 0.21957
# [1700]	valid's rmse: 0.219561
# [1720]	valid's rmse: 0.219547
# [1740]	valid's rmse: 0.219538
# [1760]	valid's rmse: 0.219523
# [1780]	valid's rmse: 0.219513
# [1800]	valid's rmse: 0.219502
# [1820]	valid's rmse: 0.219491
# [1840]	valid's rmse: 0.219482
# [1860]	valid's rmse: 0.219464
# [1880]	valid's rmse: 0.219452
# [1900]	valid's rmse: 0.219442
# [1920]	valid's rmse: 0.219422
# [1940]	valid's rmse: 0.219411
# [1960]	valid's rmse: 0.219413
# [1980]	valid's rmse: 0.219404
# [2000]	valid's rmse: 0.219386
# [2020]	valid's rmse: 0.219381
# [2040]	valid's rmse: 0.219372
# [2060]	valid's rmse: 0.219359
# [2080]	valid's rmse: 0.21935
# [2100]	valid's rmse: 0.219335
# [2120]	valid's rmse: 0.219331
# [2140]	valid's rmse: 0.219317
# [2160]	valid's rmse: 0.219305
# [2180]	valid's rmse: 0.219294
# [2200]	valid's rmse: 0.219283
# [2220]	valid's rmse: 0.219275
# [2240]	valid's rmse: 0.219266
# [2260]	valid's rmse: 0.219257
# [2280]	valid's rmse: 0.219251
# [2300]	valid's rmse: 0.21924
# [2320]	valid's rmse: 0.219227
# [2340]	valid's rmse: 0.219222
# [2360]	valid's rmse: 0.219211
# [2380]	valid's rmse: 0.219206
# [2400]	valid's rmse: 0.219202
# [2420]	valid's rmse: 0.219193
# [2440]	valid's rmse: 0.21919
# [2460]	valid's rmse: 0.219185
# [2480]	valid's rmse: 0.219181
# [2500]	valid's rmse: 0.219174
# [2520]	valid's rmse: 0.219165
# [2540]	valid's rmse: 0.219159
# [2560]	valid's rmse: 0.219147
# [2580]	valid's rmse: 0.219145
# [2600]	valid's rmse: 0.219138
# [2620]	valid's rmse: 0.219131
# [2640]	valid's rmse: 0.21912
# [2660]	valid's rmse: 0.219116
# [2680]	valid's rmse: 0.219106
# [2700]	valid's rmse: 0.2191
# [2720]	valid's rmse: 0.219094
# [2740]	valid's rmse: 0.219087
# [2760]	valid's rmse: 0.219091
# [2780]	valid's rmse: 0.219086
# [2800]	valid's rmse: 0.219077
# [2820]	valid's rmse: 0.219075
# [2840]	valid's rmse: 0.219075
# [2860]	valid's rmse: 0.219073
# [2880]	valid's rmse: 0.219068
# [2900]	valid's rmse: 0.219064
# [2920]	valid's rmse: 0.219056
# [2940]	valid's rmse: 0.219058
# [2960]	valid's rmse: 0.219053
# [2980]	valid's rmse: 0.219045
# [3000]	valid's rmse: 0.219047
# [3020]	valid's rmse: 0.219045
# [3040]	valid's rmse: 0.219043
# [3060]	valid's rmse: 0.219037
# [3080]	valid's rmse: 0.219027
# [3100]	valid's rmse: 0.219018
# [3120]	valid's rmse: 0.219013
# [3140]	valid's rmse: 0.219004
# [3160]	valid's rmse: 0.218998
# [3180]	valid's rmse: 0.218991
# [3200]	valid's rmse: 0.218984
# [3220]	valid's rmse: 0.218979
# [3240]	valid's rmse: 0.218974
# [3260]	valid's rmse: 0.218971
# [3280]	valid's rmse: 0.218963
# [3300]	valid's rmse: 0.21896
# [3320]	valid's rmse: 0.218958
# [3340]	valid's rmse: 0.218954
# [3360]	valid's rmse: 0.218949
# [3380]	valid's rmse: 0.218945
# [3400]	valid's rmse: 0.218945
# [3420]	valid's rmse: 0.21894
# [3440]	valid's rmse: 0.218939
# [3460]	valid's rmse: 0.218937
# [3480]	valid's rmse: 0.218938
# [3500]	valid's rmse: 0.218938
# [3520]	valid's rmse: 0.218935
# [3540]	valid's rmse: 0.218938
# [3560]	valid's rmse: 0.218935
# [3580]	valid's rmse: 0.218933
# [3600]	valid's rmse: 0.218935
# [3620]	valid's rmse: 0.218933
# [3640]	valid's rmse: 0.21893
# [3660]	valid's rmse: 0.218929
# [3680]	valid's rmse: 0.218921
# [3700]	valid's rmse: 0.218921
# [3720]	valid's rmse: 0.218913
# [3740]	valid's rmse: 0.218905
# [3760]	valid's rmse: 0.218902
# [3780]	valid's rmse: 0.218898
# [3800]	valid's rmse: 0.218896
# [3820]	valid's rmse: 0.218898
# [3840]	valid's rmse: 0.218893
# [3860]	valid's rmse: 0.21888
# [3880]	valid's rmse: 0.218884
# [3900]	valid's rmse: 0.218883
# Early stopping, best iteration is:
# [3861]	valid's rmse: 0.218879
# Model Evaluation Stage
# RMSE: 0.21887929724111202

# %%
# Feature Importance Plot
f, ax = plt.subplots(figsize=[7, 10])
lgb.plot_importance(lgb_clf, max_num_features=50, ax=ax)
plt.title("Light GBM Feature Importance")
plt.savefig('feature_importance.png')

# %%
f, ax = plt.subplots(figsize=[7, 10])
lgb.plot_importance(lgb_clf, max_num_features=50, ax=ax, importance_type='gain')
plt.title("Light GBM Feature Importance(gain)")
plt.savefig('feature_importance_gain.png')

# %%
lgpred = lgb_clf.predict(testing)
del testing;
gc.collect()
# Out:
# /Users/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:447: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# 43

# %%
lgsub = pd.DataFrame(lgpred, columns=["deal_probability"], index=testdex)
lgsub['deal_probability'].clip(0.0, 1.0, inplace=True)  # Between 0 and 1
lgsub.to_csv("lgsub.csv", index=True, header=True)
print("Model Runtime: %0.2f Minutes" % ((time.time() - modelstart) / 60))
print("Notebook Runtime: %0.2f Minutes" % ((time.time() - notebookstart) / 60))
# Out:
# Model Runtime: 74.77 Minutes
# Notebook Runtime: 89.69 Minutes
